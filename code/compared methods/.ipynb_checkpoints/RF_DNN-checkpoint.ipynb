# %%
import math
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
from sklearn import preprocessing

import numpy as np
import pandas as pd

import time
import random
import matplotlib.pyplot as plt
from scipy import interp
import warnings
warnings.filterwarnings("ignore")

from sklearn.ensemble import RandomForestClassifier
from collections import Counter
from tqdm import tqdm

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve

# %%
def load_data(directory):
    GSSM = np.loadtxt(directory + '\GSSM_.txt',dtype=np.float32)
    PESSM = np.loadtxt(directory + '\PSSM.txt',dtype=np.float32,delimiter='\t')

    IPE = pd.DataFrame(PESSM).reset_index()
    IG = pd.DataFrame(GSSM).reset_index()
    IPE.rename(columns = {'index':'id'}, inplace = True)
    IG.rename(columns = {'index':'id'}, inplace = True)
    IPE['id'] = IPE['id']
    IG['id'] = IG['id']
    
    return IPE, IG

# def sample(directory, random_seed):
#     all_associations = pd.read_csv(directory + '/all_gpe_pairs.csv')
#     known_associations = all_associations.loc[all_associations['label'] == 1]
#     unknown_associations = all_associations.loc[all_associations['label'] == 0]
#     random_negative = unknown_associations.sample(n=known_associations.shape[0], random_state=random_seed, axis=0)

#     sample_df = known_associations.append(random_negative)
#     sample_df.reset_index(drop=True, inplace=True)

#     return sample_df

def sample(directory, random_seed):
    all_associations = pd.read_csv(directory + '/all_gpe_pairs.csv')
    known_associations = all_associations.loc[all_associations['label'] == 1]
    peco_ids = list(set(known_associations['peco_idx']))
    unknown_associations = all_associations.loc[all_associations['label'] == 0]
    sample_df = known_associations
    for peco_id in peco_ids:
        random_negative = unknown_associations.loc[all_associations['peco_idx'] == peco_id].sample(n=known_associations.loc[all_associations['peco_idx'] == peco_id].shape[0], random_state=random_seed, axis=0, replace=True)

        sample_df = pd.concat([sample_df,random_negative], axis=0)

    sample_df.reset_index(drop=True, inplace=True)

    return sample_df

# %%
def performances(y_true, y_pred, y_prob):

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels = [0, 1]).ravel().tolist()

    pos_acc = tp / sum(y_true)
    neg_acc = tn / (len(y_pred) - sum(y_pred)) # [y_true=0 & y_pred=0] / y_pred=0
    accuracy = (tp+tn)/(tn+fp+fn+tp)
    
    recall = tp / (tp+fn)
    precision = tp / (tp+fp)
    f1 = 2*precision*recall / (precision+recall)
    
    roc_auc = roc_auc_score(y_true, y_prob)
    prec, reca, _ = precision_recall_curve(y_true, y_prob)
    aupr = auc(reca, prec)
    
    print('tn = {}, fp = {}, fn = {}, tp = {}'.format(tn, fp, fn, tp))
    print('y_pred: 0 = {} | 1 = {}'.format(Counter(y_pred)[0], Counter(y_pred)[1]))
    print('y_true: 0 = {} | 1 = {}'.format(Counter(y_true)[0], Counter(y_true)[1]))
    print('acc={:.4f}|precision={:.4f}|recall={:.4f}|f1={:.4f}|auc={:.4f}|aupr={:.4f}|pos_acc={:.4f}|neg_acc={:.4f}'.format(accuracy, precision, recall, f1, roc_auc, aupr, pos_acc, neg_acc))
    return (y_true, y_pred, y_prob), (accuracy, precision, recall, f1, roc_auc, aupr, pos_acc, neg_acc)

# %%
def obtain_data(directory, isbalance):

    IPE, IG = load_data(directory)

    if isbalance:
        dtp = sample(directory, random_seed = 1234)
    else:
        dtp = pd.read_csv(directory + '/all_gene_peco_pairs.csv')

    gene_ids = list(set(dtp['gene_idx']))
    peco_ids = list(set(dtp['peco_idx']))
    random.shuffle(gene_ids)
    random.shuffle(peco_ids)
    print('# gene = {} | peco = {}'.format(len(gene_ids), len(peco_ids)))

    gene_test_num = int(len(gene_ids) / 5)
    peco_test_num = int(len(peco_ids) / 5)
    print('# Test: gene = {} | peco = {}'.format(gene_test_num, peco_test_num))    
    
    samples = pd.merge(pd.merge(dtp, IPE, left_on = 'peco_idx', right_on = 'id'), IG, left_on = 'gene_idx', right_on = 'id')
    samples.drop(labels = ['id_x', 'id_y'], axis = 1, inplace = True)
    
    return IPE, IG, dtp, gene_ids, peco_ids, gene_test_num, peco_test_num, samples

# %%
def generate_task_Tp_train_test_idx(samples):
    kf = KFold(n_splits = 5, shuffle = True, random_state = 1234)

    train_index_all, test_index_all, n = [], [], 0
    train_id_all, test_id_all = [], []
    fold = 0
    for train_idx, test_idx in tqdm(kf.split(samples.iloc[:, 3:])): #train_index与test_index为下标
        print('-------Fold ', fold)
        train_index_all.append(train_idx) 
        test_index_all.append(test_idx)

        train_id_all.append(np.array(dtp.iloc[train_idx][['gene_idx', 'peco_idx']]))
        test_id_all.append(np.array(dtp.iloc[test_idx][['gene_idx', 'peco_idx']]))

        print('# Pairs: Train = {} | Test = {}'.format(len(train_idx), len(test_idx)))
        fold += 1
    return train_index_all, test_index_all, train_id_all, test_id_all

# %%
def generate_task_Tg_Tpe_train_test_idx(item, ids, dtp):
    
    test_num = int(len(ids) / 5)
    
    train_index_all, test_index_all = [], []
    train_id_all, test_id_all = [], []
    
    for fold in range(5):
        print('-------Fold ', fold)
        if fold != 4:
            test_ids = ids[fold * test_num : (fold + 1) * test_num]
        else:
            test_ids = ids[fold * test_num :]

        train_ids = list(set(ids) ^ set(test_ids))
        print('# {}: Train = {} | Test = {}'.format(item, len(train_ids), len(test_ids)))

        test_idx = dtp[dtp[item].isin(test_ids)].index.tolist()
        train_idx = dtp[dtp[item].isin(train_ids)].index.tolist()
        random.shuffle(test_idx)
        random.shuffle(train_idx)
        print('# Pairs: Train = {} | Test = {}'.format(len(train_idx), len(test_idx)))
        assert len(train_idx) + len(test_idx) == len(dtp)

        train_index_all.append(train_idx) 
        test_index_all.append(test_idx)
        
        train_id_all.append(train_ids)
        test_id_all.append(test_ids)
        
    return train_index_all, test_index_all, train_id_all, test_id_all

# %% [markdown]
# # 随机森林

# %%
def run_rf(train_index_all, test_index_all, samples):
    
    fold = 0
    for train_idx, test_idx in zip(train_index_all, test_index_all):
        print('-----------------------Fold = ', str(fold))

        X = samples.iloc[:, 3:]
        y = samples['label']

        scaler = preprocessing.MinMaxScaler().fit(X.iloc[train_idx,:])
        X = scaler.transform(X)

        x_train, y_train = X[train_idx], y[train_idx]
        x_test, y_test = X[test_idx], y[test_idx]

        clf = RandomForestClassifier(random_state = 19961231)
        clf.fit(x_train, y_train)

        y_train_prob = clf.predict_proba(x_train)
        y_test_prob = clf.predict_proba(x_test)

        y_train_pred = clf.predict(x_train)
        y_test_pred = clf.predict(x_test)

        print('Train:')
        ys_train, metrics_train = performances(y_train, y_train_pred, y_train_prob[:, 1])
        print('Test:')
        ys_test, metrics_test = performances(y_test, y_test_pred, y_test_prob[:, 1])

        fold += 1
        
    return ys_train, metrics_train, ys_test, metrics_test

# %% [markdown]
# # DNN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.metrics import *
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import roc_auc_score, auc, precision_recall_curve, confusion_matrix
import numpy as np
import sklearn.metrics as metrics
from collections import Counter
from sklearn import preprocessing
from tensorflow.keras import backend as K

# %%
def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.
    #F-beta分数是精度和召回率的加权调和平均值，达到1时为最佳值，0时为最差值
    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
        
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0.0:
        return 0.0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def f1(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

def transfer(y_pred):
    return [[0,1][x>0.5] for x in y_pred.reshape(-1)]

# %%
def Model(x):
    #Sequential 是实现全连接网络，下面逐层添加网络结构
    model = Sequential()
    model.add(Dense(1024, activation='elu', input_shape=(x.shape[1],)))
    model.add(Dense(512, activation='elu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    #优化器为Adam
    #optimizer = Adam(lr = 0.0001)
    model.compile(optimizer = 'Adam', loss = binary_crossentropy, metrics=[binary_accuracy, f1, recall, precision])
    return model

# %%
def run_dnn(train_index_all, test_index_all, samples):
    
    fold = 0
    for train_idx, test_idx in zip(train_index_all, test_index_all):
        print('----------------------- Fold = ', str(fold))

        X = samples.iloc[:, 3:]
        y = samples['label']

        scaler = preprocessing.MinMaxScaler().fit(X.iloc[train_idx,:])
        X = scaler.transform(X)

        x_train, y_train = X[train_idx], y[train_idx]
        x_test, y_test = X[test_idx], y[test_idx]

        model = Model(x_train)
        early_stopping = EarlyStopping(monitor='val_loss', patience = 50)
        model.fit(x_train, y_train, epochs = 500, batch_size = 250, validation_data=(x_test, y_test), callbacks=[early_stopping],verbose = 1)

        y_train_pred, y_test_pred = model.predict(x_train, verbose = 0), model.predict(x_test, verbose = 0)
        y_train_prob, y_test_prob = model.predict_proba(x_train), model.predict_proba(x_test)

        if len(Counter(y_train_pred.reshape(-1))) > 2: 
            y_train_pred = transfer(y_train_pred)
        else:
            print(Counter(y_train_pred.reshape(-1)))
        if len(Counter(y_test_pred.reshape(-1))) > 2: 
            y_test_pred = transfer(y_test_pred)
        else:
            print(Counter(y_test_pred.reshape(-1)))

        performances_train = performances(y_train, y_train_pred, y_train_prob)
        performances_test = performances(y_test, y_test_pred, y_test_prob)

        fold += 1
    
    return y_train_pred, y_test_pred, y_train_prob, y_test_prob, performances_train, performances_test

# %% [markdown]
# # Run

# %% [markdown]
# ## RF

# %%
directory = 'D:\小麦\MDA-GCNFTG-main\MDA-GCNFTG-main\data'
for isbalance in [True]:
    
    IPE, IG, dtp, gene_ids, peco_ids, gene_test_num, peco_test_num, samples = obtain_data(directory, 
                                                                                                 isbalance)
    #for task in ['Tp', 'Tg', 'Tpe']:
    for task in ['Tp']:   
        print('========== isbalance = {} | task = {}'.format(isbalance, task))
        
        if task == 'Tp':
            train_index_all, test_index_all, train_id_all, test_id_all = generate_task_Tp_train_test_idx(samples)
            
        elif task == 'Tg':
            item = 'gene_idx'
            ids = gene_ids
            train_index_all, test_index_all, train_id_all, test_id_all = generate_task_Tg_Tpe_train_test_idx(item, ids, dtp)

        elif task == 'Tpe':
            item = 'peco_idx'
            ids = peco_ids
            train_index_all, test_index_all, train_id_all, test_id_all = generate_task_Tg_Tpe_train_test_idx(item, ids, dtp)

        ys_train, metrics_train, ys_test, metrics_test = run_rf(train_index_all, test_index_all, samples)
        fpr, tpr, thresholds = roc_curve(ys_test[0], ys_test[2])
        data = pd.DataFrame(zip(fpr, tpr), columns=['fpr','tpr']).to_csv(r'D:\小麦\MDA-GCNFTG-main\MDA-GCNFTG-main\评价指标统计图\roc\RF.csv',index=False)
# Out:
# 5it [00:00, 138.89it/s]
# # gene = 11177 | peco = 24
# # Test: gene = 2235 | peco = 4
# ========== isbalance = True | task = Tp
# -------Fold  0
# # Pairs: Train = 37692 | Test = 9424
# -------Fold  1
# # Pairs: Train = 37693 | Test = 9423
# -------Fold  2
# # Pairs: Train = 37693 | Test = 9423
# -------Fold  3
# # Pairs: Train = 37693 | Test = 9423
# -------Fold  4
# # Pairs: Train = 37693 | Test = 9423
# -----------------------Fold =  0
# Train:
# tn = 18890, fp = 0, fn = 0, tp = 18802
# y_pred: 0 = 18890 | 1 = 18802
# y_true: 0 = 18890 | 1 = 18802
# acc=1.0000|precision=1.0000|recall=1.0000|f1=1.0000|auc=1.0000|aupr=1.0000|pos_acc=1.0000|neg_acc=1.0000
# Test:
# tn = 3971, fp = 697, fn = 638, tp = 4118
# y_pred: 0 = 4609 | 1 = 4815
# y_true: 0 = 4668 | 1 = 4756
# acc=0.8583|precision=0.8552|recall=0.8659|f1=0.8605|auc=0.9399|aupr=0.9441|pos_acc=0.8659|neg_acc=0.8616
# -----------------------Fold =  1
# Train:
# tn = 18821, fp = 0, fn = 1, tp = 18871
# y_pred: 0 = 18822 | 1 = 18871
# y_true: 0 = 18821 | 1 = 18872
# acc=1.0000|precision=1.0000|recall=0.9999|f1=1.0000|auc=1.0000|aupr=1.0000|pos_acc=0.9999|neg_acc=0.9999
# Test:
# tn = 4025, fp = 712, fn = 605, tp = 4081
# y_pred: 0 = 4630 | 1 = 4793
# y_true: 0 = 4737 | 1 = 4686
# acc=0.8602|precision=0.8515|recall=0.8709|f1=0.8611|auc=0.9422|aupr=0.9435|pos_acc=0.8709|neg_acc=0.8693
# -----------------------Fold =  2
# Train:
# tn = 18881, fp = 0, fn = 1, tp = 18811
# y_pred: 0 = 18882 | 1 = 18811
# y_true: 0 = 18881 | 1 = 18812
# acc=1.0000|precision=1.0000|recall=0.9999|f1=1.0000|auc=1.0000|aupr=1.0000|pos_acc=0.9999|neg_acc=0.9999
# Test:
# tn = 3991, fp = 686, fn = 649, tp = 4097
# y_pred: 0 = 4640 | 1 = 4783
# y_true: 0 = 4677 | 1 = 4746
# acc=0.8583|precision=0.8566|recall=0.8633|f1=0.8599|auc=0.9393|aupr=0.9399|pos_acc=0.8633|neg_acc=0.8601
# -----------------------Fold =  3
# Train:
# tn = 18793, fp = 1, fn = 0, tp = 18899
# y_pred: 0 = 18793 | 1 = 18900
# y_true: 0 = 18794 | 1 = 18899
# acc=1.0000|precision=0.9999|recall=1.0000|f1=1.0000|auc=1.0000|aupr=1.0000|pos_acc=1.0000|neg_acc=1.0000
# Test:
# tn = 4045, fp = 719, fn = 635, tp = 4024
# y_pred: 0 = 4680 | 1 = 4743
# y_true: 0 = 4764 | 1 = 4659
# acc=0.8563|precision=0.8484|recall=0.8637|f1=0.8560|auc=0.9393|aupr=0.9380|pos_acc=0.8637|neg_acc=0.8643
# -----------------------Fold =  4
# Train:
# tn = 18846, fp = 0, fn = 1, tp = 18846
# y_pred: 0 = 18847 | 1 = 18846
# y_true: 0 = 18846 | 1 = 18847
# acc=1.0000|precision=1.0000|recall=0.9999|f1=1.0000|auc=1.0000|aupr=1.0000|pos_acc=0.9999|neg_acc=0.9999
# Test:
# tn = 3985, fp = 727, fn = 620, tp = 4091
# y_pred: 0 = 4605 | 1 = 4818
# y_true: 0 = 4712 | 1 = 4711
# acc=0.8571|precision=0.8491|recall=0.8684|f1=0.8586|auc=0.9405|aupr=0.9425|pos_acc=0.8684|neg_acc=0.8654

# %% [markdown]
# ## DNN

# %%
directory = 'D:\小麦\MDA-GCNFTG-main\MDA-GCNFTG-main\data'
for isbalance in [True]:
    
    IPE, IG, dtp, gene_ids, peco_ids, gene_test_num, peco_test_num, samples = obtain_data(directory, 
                                                                                                 isbalance)
    #for task in ['Tp', 'Tg', 'Tpe']:
    for task in ['Tp']:   
        print('========== isbalance = {} | task = {}'.format(isbalance, task))
        
        if task == 'Tp':
            train_index_all, test_index_all, train_id_all, test_id_all = generate_task_Tp_train_test_idx(samples)
            
        elif task == 'Tg':
            item = 'gene_idx'
            ids = gene_ids
            train_index_all, test_index_all, train_id_all, test_id_all = generate_task_Tg_Tpe_train_test_idx(item, ids, dtp)

        elif task == 'Tpe':
            item = 'peco_idx'
            ids = peco_ids
            train_index_all, test_index_all, train_id_all, test_id_all = generate_task_Tg_Tpe_train_test_idx(item, ids, dtp)

        y_train_pred, y_test_pred, y_train_prob, y_test_prob, performances_train, performances_test = run_dnn(train_index_all, test_index_all, samples)
        fpr, tpr, thresholds = roc_curve(ys_test[0], ys_test[2])
        data = pd.DataFrame(zip(fpr, tpr), columns=['fpr','tpr']).to_csv(r'D:\小麦\MDA-GCNFTG-main\MDA-GCNFTG-main\评价指标统计图\roc\DNN.csv',index=False)
# Out:
# 5it [00:00, 208.40it/s]
# # gene = 11177 | peco = 24
# # Test: gene = 2235 | peco = 4
# ========== isbalance = True | task = Tp
# -------Fold  0
# # Pairs: Train = 37692 | Test = 9424
# -------Fold  1
# # Pairs: Train = 37693 | Test = 9423
# -------Fold  2
# # Pairs: Train = 37693 | Test = 9423
# -------Fold  3
# # Pairs: Train = 37693 | Test = 9423
# -------Fold  4
# # Pairs: Train = 37693 | Test = 9423
# Epoch 1/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.3798 - binary_accuracy: 0.8152 - f1: 0.8132 - recall: 0.8161 - precision: 0.8363 - val_loss: 0.3044 - val_binary_accuracy: 0.8630 - val_f1: 0.8619 - val_recall: 0.8521 - val_precision: 0.8796
# Epoch 2/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3081 - binary_accuracy: 0.8583 - f1: 0.8596 - recall: 0.8773 - precision: 0.8454 - val_loss: 0.3035 - val_binary_accuracy: 0.8588 - val_f1: 0.8631 - val_recall: 0.8938 - val_precision: 0.8407
# Epoch 3/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.3073 - binary_accuracy: 0.8579 - f1: 0.8583 - recall: 0.8700 - precision: 0.8491 - val_loss: 0.3031 - val_binary_accuracy: 0.8542 - val_f1: 0.8621 - val_recall: 0.9211 - val_precision: 0.8156
# Epoch 4/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.3051 - binary_accuracy: 0.8574 - f1: 0.8592 - recall: 0.8814 - precision: 0.8408 - val_loss: 0.3030 - val_binary_accuracy: 0.8615 - val_f1: 0.8638 - val_recall: 0.8765 - val_precision: 0.8588
# Epoch 5/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.3042 - binary_accuracy: 0.8590 - f1: 0.8602 - recall: 0.8788 - precision: 0.8443 - val_loss: 0.3028 - val_binary_accuracy: 0.8581 - val_f1: 0.8630 - val_recall: 0.8999 - val_precision: 0.8351
# Epoch 6/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.3035 - binary_accuracy: 0.8586 - f1: 0.8618 - recall: 0.8834 - precision: 0.8427 - val_loss: 0.3028 - val_binary_accuracy: 0.8606 - val_f1: 0.8597 - val_recall: 0.8509 - val_precision: 0.8759
# Epoch 7/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.3026 - binary_accuracy: 0.8564 - f1: 0.8584 - recall: 0.8791 - precision: 0.8411 - val_loss: 0.3017 - val_binary_accuracy: 0.8583 - val_f1: 0.8640 - val_recall: 0.9056 - val_precision: 0.8320
# Epoch 8/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.2999 - binary_accuracy: 0.8586 - f1: 0.8614 - recall: 0.8818 - precision: 0.8442 - val_loss: 0.3036 - val_binary_accuracy: 0.8562 - val_f1: 0.8622 - val_recall: 0.9052 - val_precision: 0.8292
# Epoch 9/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3055 - binary_accuracy: 0.8564 - f1: 0.8583 - recall: 0.8802 - precision: 0.8395 - val_loss: 0.3068 - val_binary_accuracy: 0.8573 - val_f1: 0.8627 - val_recall: 0.9016 - val_precision: 0.8331
# Epoch 10/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3019 - binary_accuracy: 0.8569 - f1: 0.8579 - recall: 0.8708 - precision: 0.8492 - val_loss: 0.3033 - val_binary_accuracy: 0.8562 - val_f1: 0.8593 - val_recall: 0.8811 - val_precision: 0.8448
# Epoch 11/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3020 - binary_accuracy: 0.8604 - f1: 0.8611 - recall: 0.8752 - precision: 0.8493 - val_loss: 0.3026 - val_binary_accuracy: 0.8607 - val_f1: 0.8606 - val_recall: 0.8556 - val_precision: 0.8733
# Epoch 12/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2999 - binary_accuracy: 0.8572 - f1: 0.8593 - recall: 0.8801 - precision: 0.8420 - val_loss: 0.3049 - val_binary_accuracy: 0.8523 - val_f1: 0.8605 - val_recall: 0.9211 - val_precision: 0.8129
# Epoch 13/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2986 - binary_accuracy: 0.8603 - f1: 0.8639 - recall: 0.8870 - precision: 0.8437 - val_loss: 0.3053 - val_binary_accuracy: 0.8563 - val_f1: 0.8627 - val_recall: 0.9092 - val_precision: 0.8266
# Epoch 14/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2994 - binary_accuracy: 0.8619 - f1: 0.8638 - recall: 0.8806 - precision: 0.8492 - val_loss: 0.3110 - val_binary_accuracy: 0.8519 - val_f1: 0.8611 - val_recall: 0.9301 - val_precision: 0.8067
# Epoch 15/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.3049 - binary_accuracy: 0.8558 - f1: 0.8590 - recall: 0.8856 - precision: 0.8373 - val_loss: 0.3029 - val_binary_accuracy: 0.8619 - val_f1: 0.8637 - val_recall: 0.8724 - val_precision: 0.8627
# Epoch 16/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.3063 - binary_accuracy: 0.8581 - f1: 0.8587 - recall: 0.8714 - precision: 0.8481 - val_loss: 0.3015 - val_binary_accuracy: 0.8630 - val_f1: 0.8637 - val_recall: 0.8665 - val_precision: 0.8683
# Epoch 17/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.2943 - binary_accuracy: 0.8625 - f1: 0.8659 - recall: 0.8874 - precision: 0.8474 - val_loss: 0.3080 - val_binary_accuracy: 0.8525 - val_f1: 0.8613 - val_recall: 0.9287 - val_precision: 0.8082
# Epoch 18/500
# 151/151 [==============================] - 2s 10ms/step - loss: 0.2996 - binary_accuracy: 0.8594 - f1: 0.8657 - recall: 0.9036 - precision: 0.8328 - val_loss: 0.3047 - val_binary_accuracy: 0.8626 - val_f1: 0.8609 - val_recall: 0.8486 - val_precision: 0.8814
# Epoch 19/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3023 - binary_accuracy: 0.8607 - f1: 0.8617 - recall: 0.8772 - precision: 0.8487 - val_loss: 0.3026 - val_binary_accuracy: 0.8622 - val_f1: 0.8646 - val_recall: 0.8808 - val_precision: 0.8561
# Epoch 20/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3038 - binary_accuracy: 0.8590 - f1: 0.8608 - recall: 0.8812 - precision: 0.8432 - val_loss: 0.3039 - val_binary_accuracy: 0.8618 - val_f1: 0.8653 - val_recall: 0.8879 - val_precision: 0.8508
# Epoch 21/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2944 - binary_accuracy: 0.8645 - f1: 0.8664 - recall: 0.8827 - precision: 0.8522 - val_loss: 0.3055 - val_binary_accuracy: 0.8555 - val_f1: 0.8627 - val_recall: 0.9176 - val_precision: 0.8195
# Epoch 22/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3010 - binary_accuracy: 0.8584 - f1: 0.8607 - recall: 0.8837 - precision: 0.8411 - val_loss: 0.3025 - val_binary_accuracy: 0.8616 - val_f1: 0.8637 - val_recall: 0.8766 - val_precision: 0.8584
# Epoch 23/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3009 - binary_accuracy: 0.8617 - f1: 0.8651 - recall: 0.8848 - precision: 0.8482 - val_loss: 0.3047 - val_binary_accuracy: 0.8593 - val_f1: 0.8643 - val_recall: 0.9017 - val_precision: 0.8358
# Epoch 24/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2989 - binary_accuracy: 0.8625 - f1: 0.8659 - recall: 0.8898 - precision: 0.8445 - val_loss: 0.3024 - val_binary_accuracy: 0.8619 - val_f1: 0.8639 - val_recall: 0.8746 - val_precision: 0.8607
# Epoch 25/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3056 - binary_accuracy: 0.8594 - f1: 0.8600 - recall: 0.8771 - precision: 0.8454 - val_loss: 0.3050 - val_binary_accuracy: 0.8555 - val_f1: 0.8627 - val_recall: 0.9178 - val_precision: 0.8195
# Epoch 26/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3034 - binary_accuracy: 0.8602 - f1: 0.8628 - recall: 0.8859 - precision: 0.8425 - val_loss: 0.3064 - val_binary_accuracy: 0.8548 - val_f1: 0.8623 - val_recall: 0.9174 - val_precision: 0.81910.3050 - binary_accuracy: 0.8598 - f1: 0.8630 - recall: 0.8904 - precisi
# Epoch 27/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2999 - binary_accuracy: 0.8621 - f1: 0.8659 - recall: 0.8914 - precision: 0.8435 - val_loss: 0.3018 - val_binary_accuracy: 0.8633 - val_f1: 0.8635 - val_recall: 0.8646 - val_precision: 0.8698
# Epoch 28/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2990 - binary_accuracy: 0.8624 - f1: 0.8651 - recall: 0.8858 - precision: 0.8476 - val_loss: 0.3052 - val_binary_accuracy: 0.8553 - val_f1: 0.8622 - val_recall: 0.9154 - val_precision: 0.8205
# Epoch 29/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2993 - binary_accuracy: 0.8614 - f1: 0.8635 - recall: 0.8810 - precision: 0.8480 - val_loss: 0.3039 - val_binary_accuracy: 0.8619 - val_f1: 0.8660 - val_recall: 0.8946 - val_precision: 0.8454
# Epoch 30/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2977 - binary_accuracy: 0.8616 - f1: 0.8656 - recall: 0.8936 - precision: 0.8406 - val_loss: 0.3048 - val_binary_accuracy: 0.8624 - val_f1: 0.8635 - val_recall: 0.8689 - val_precision: 0.8653
# Epoch 31/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3009 - binary_accuracy: 0.8641 - f1: 0.8657 - recall: 0.8809 - precision: 0.8524 - val_loss: 0.3051 - val_binary_accuracy: 0.8622 - val_f1: 0.8630 - val_recall: 0.8668 - val_precision: 0.8663
# Epoch 32/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.3007 - binary_accuracy: 0.8600 - f1: 0.8627 - recall: 0.8876 - precision: 0.8414 - val_loss: 0.3018 - val_binary_accuracy: 0.8619 - val_f1: 0.8644 - val_recall: 0.8797 - val_precision: 0.8566
# Epoch 33/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.3006 - binary_accuracy: 0.8596 - f1: 0.8614 - recall: 0.8774 - precision: 0.8476 - val_loss: 0.3023 - val_binary_accuracy: 0.8616 - val_f1: 0.8657 - val_recall: 0.8929 - val_precision: 0.8464
# Epoch 34/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3050 - binary_accuracy: 0.8585 - f1: 0.8598 - recall: 0.8760 - precision: 0.8452 - val_loss: 0.3012 - val_binary_accuracy: 0.8624 - val_f1: 0.8642 - val_recall: 0.8752 - val_precision: 0.8607
# Epoch 35/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3003 - binary_accuracy: 0.8593 - f1: 0.8612 - recall: 0.8821 - precision: 0.8430 - val_loss: 0.3039 - val_binary_accuracy: 0.8578 - val_f1: 0.8619 - val_recall: 0.8916 - val_precision: 0.8404
# Epoch 36/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3010 - binary_accuracy: 0.8604 - f1: 0.8616 - recall: 0.8765 - precision: 0.8482 - val_loss: 0.3018 - val_binary_accuracy: 0.8625 - val_f1: 0.8642 - val_recall: 0.8739 - val_precision: 0.8621
# Epoch 37/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2997 - binary_accuracy: 0.8615 - f1: 0.8622 - recall: 0.8749 - precision: 0.8509 - val_loss: 0.3035 - val_binary_accuracy: 0.8542 - val_f1: 0.8616 - val_recall: 0.9138 - val_precision: 0.8208
# Epoch 38/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3041 - binary_accuracy: 0.8569 - f1: 0.8594 - recall: 0.8853 - precision: 0.8363 - val_loss: 0.3023 - val_binary_accuracy: 0.8625 - val_f1: 0.8637 - val_recall: 0.8687 - val_precision: 0.8660
# Epoch 39/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2963 - binary_accuracy: 0.8630 - f1: 0.8634 - recall: 0.8753 - precision: 0.8530 - val_loss: 0.3046 - val_binary_accuracy: 0.8598 - val_f1: 0.8622 - val_recall: 0.8781 - val_precision: 0.8535
# Epoch 40/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2992 - binary_accuracy: 0.8600 - f1: 0.8625 - recall: 0.8831 - precision: 0.8441 - val_loss: 0.3041 - val_binary_accuracy: 0.8626 - val_f1: 0.8654 - val_recall: 0.8838 - val_precision: 0.8546
# Epoch 41/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.3028 - binary_accuracy: 0.8574 - f1: 0.8607 - recall: 0.8850 - precision: 0.8391 - val_loss: 0.3025 - val_binary_accuracy: 0.8607 - val_f1: 0.8613 - val_recall: 0.8630 - val_precision: 0.8669
# Epoch 42/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2920 - binary_accuracy: 0.8641 - f1: 0.8675 - recall: 0.8860 - precision: 0.8518 - val_loss: 0.3023 - val_binary_accuracy: 0.8596 - val_f1: 0.8618 - val_recall: 0.8732 - val_precision: 0.8578
# Epoch 43/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2980 - binary_accuracy: 0.8607 - f1: 0.8633 - recall: 0.8822 - precision: 0.8462 - val_loss: 0.3016 - val_binary_accuracy: 0.8614 - val_f1: 0.8602 - val_recall: 0.8520 - val_precision: 0.8760
# Epoch 44/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2967 - binary_accuracy: 0.8621 - f1: 0.8628 - recall: 0.8766 - precision: 0.8511 - val_loss: 0.3019 - val_binary_accuracy: 0.8621 - val_f1: 0.8629 - val_recall: 0.8668 - val_precision: 0.8663
# Epoch 45/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.3031 - binary_accuracy: 0.8610 - f1: 0.8634 - recall: 0.8798 - precision: 0.8492 - val_loss: 0.3053 - val_binary_accuracy: 0.8615 - val_f1: 0.8625 - val_recall: 0.8681 - val_precision: 0.8641
# Epoch 46/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2964 - binary_accuracy: 0.8635 - f1: 0.8644 - recall: 0.8748 - precision: 0.8552 - val_loss: 0.3047 - val_binary_accuracy: 0.8610 - val_f1: 0.8635 - val_recall: 0.8793 - val_precision: 0.8549
# Epoch 47/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2957 - binary_accuracy: 0.8633 - f1: 0.8653 - recall: 0.8856 - precision: 0.8472 - val_loss: 0.3017 - val_binary_accuracy: 0.8631 - val_f1: 0.8671 - val_recall: 0.8969 - val_precision: 0.8451
# Epoch 48/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.3005 - binary_accuracy: 0.8592 - f1: 0.8612 - recall: 0.8753 - precision: 0.8484 - val_loss: 0.3040 - val_binary_accuracy: 0.8612 - val_f1: 0.8632 - val_recall: 0.8741 - val_precision: 0.8595
# Epoch 49/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2990 - binary_accuracy: 0.8603 - f1: 0.8627 - recall: 0.8809 - precision: 0.8467 - val_loss: 0.3016 - val_binary_accuracy: 0.8616 - val_f1: 0.8662 - val_recall: 0.8999 - val_precision: 0.8411
# Epoch 50/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2989 - binary_accuracy: 0.8615 - f1: 0.8636 - recall: 0.8781 - precision: 0.8512 - val_loss: 0.3033 - val_binary_accuracy: 0.8631 - val_f1: 0.8649 - val_recall: 0.8745 - val_precision: 0.8628
# Epoch 51/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2996 - binary_accuracy: 0.8594 - f1: 0.8615 - recall: 0.8831 - precision: 0.8425 - val_loss: 0.3039 - val_binary_accuracy: 0.8562 - val_f1: 0.8617 - val_recall: 0.9045 - val_precision: 0.8285
# Epoch 52/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2990 - binary_accuracy: 0.8616 - f1: 0.8608 - recall: 0.8762 - precision: 0.8480 - val_loss: 0.3032 - val_binary_accuracy: 0.8606 - val_f1: 0.8616 - val_recall: 0.8676 - val_precision: 0.8629
# Epoch 53/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2996 - binary_accuracy: 0.8628 - f1: 0.8637 - recall: 0.8808 - precision: 0.8482 - val_loss: 0.3054 - val_binary_accuracy: 0.8552 - val_f1: 0.8622 - val_recall: 0.9163 - val_precision: 0.8195
# Epoch 54/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2967 - binary_accuracy: 0.8633 - f1: 0.8667 - recall: 0.8985 - precision: 0.8388 - val_loss: 0.3040 - val_binary_accuracy: 0.8583 - val_f1: 0.8634 - val_recall: 0.9006 - val_precision: 0.8349
# Epoch 55/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2985 - binary_accuracy: 0.8607 - f1: 0.8609 - recall: 0.8764 - precision: 0.8474 - val_loss: 0.3017 - val_binary_accuracy: 0.8606 - val_f1: 0.8623 - val_recall: 0.8716 - val_precision: 0.8604
# Epoch 56/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2926 - binary_accuracy: 0.8626 - f1: 0.8639 - recall: 0.8803 - precision: 0.8490 - val_loss: 0.3050 - val_binary_accuracy: 0.8631 - val_f1: 0.8640 - val_recall: 0.8684 - val_precision: 0.8669
# Epoch 57/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2991 - binary_accuracy: 0.8611 - f1: 0.8626 - recall: 0.8811 - precision: 0.8461 - val_loss: 0.3032 - val_binary_accuracy: 0.8626 - val_f1: 0.8647 - val_recall: 0.8809 - val_precision: 0.8555
# Epoch 58/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2987 - binary_accuracy: 0.8597 - f1: 0.8619 - recall: 0.8790 - precision: 0.8464 - val_loss: 0.3025 - val_binary_accuracy: 0.8621 - val_f1: 0.8646 - val_recall: 0.8810 - val_precision: 0.8552
# Epoch 59/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2908 - binary_accuracy: 0.8643 - f1: 0.8664 - recall: 0.8835 - precision: 0.8509 - val_loss: 0.3052 - val_binary_accuracy: 0.8592 - val_f1: 0.8654 - val_recall: 0.9093 - val_precision: 0.8310
# Epoch 60/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2897 - binary_accuracy: 0.8622 - f1: 0.8671 - recall: 0.8957 - precision: 0.8416 - val_loss: 0.3024 - val_binary_accuracy: 0.8615 - val_f1: 0.8635 - val_recall: 0.8739 - val_precision: 0.8604
# Epoch 61/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2893 - binary_accuracy: 0.8653 - f1: 0.8674 - recall: 0.8818 - precision: 0.8545 - val_loss: 0.3033 - val_binary_accuracy: 0.8588 - val_f1: 0.8624 - val_recall: 0.8919 - val_precision: 0.8406
# Epoch 62/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2973 - binary_accuracy: 0.8612 - f1: 0.8641 - recall: 0.8808 - precision: 0.8493 - val_loss: 0.3058 - val_binary_accuracy: 0.8586 - val_f1: 0.8626 - val_recall: 0.8933 - val_precision: 0.8400
# Epoch 63/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2927 - binary_accuracy: 0.8643 - f1: 0.8661 - recall: 0.8837 - precision: 0.8500 - val_loss: 0.3043 - val_binary_accuracy: 0.8617 - val_f1: 0.8644 - val_recall: 0.8826 - val_precision: 0.8536
# Epoch 64/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2930 - binary_accuracy: 0.8657 - f1: 0.8671 - recall: 0.8824 - precision: 0.8536 - val_loss: 0.3046 - val_binary_accuracy: 0.8589 - val_f1: 0.8625 - val_recall: 0.8890 - val_precision: 0.8440
# Epoch 65/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2928 - binary_accuracy: 0.8637 - f1: 0.8649 - recall: 0.8829 - precision: 0.8486 - val_loss: 0.3104 - val_binary_accuracy: 0.8576 - val_f1: 0.8586 - val_recall: 0.8654 - val_precision: 0.8587
# Epoch 66/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2983 - binary_accuracy: 0.8618 - f1: 0.8642 - recall: 0.8859 - precision: 0.8447 - val_loss: 0.3050 - val_binary_accuracy: 0.8618 - val_f1: 0.8639 - val_recall: 0.8769 - val_precision: 0.8576
# Epoch 67/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2885 - binary_accuracy: 0.8646 - f1: 0.8664 - recall: 0.8887 - precision: 0.8464 - val_loss: 0.3079 - val_binary_accuracy: 0.8587 - val_f1: 0.8624 - val_recall: 0.8878 - val_precision: 0.8448
# Epoch 68/500
# 151/151 [==============================] - 2s 13ms/step - loss: 0.2893 - binary_accuracy: 0.8648 - f1: 0.8660 - recall: 0.8797 - precision: 0.8538 - val_loss: 0.3080 - val_binary_accuracy: 0.8604 - val_f1: 0.8626 - val_recall: 0.8769 - val_precision: 0.8553
# Epoch 69/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2901 - binary_accuracy: 0.8659 - f1: 0.8667 - recall: 0.8843 - precision: 0.8512 - val_loss: 0.3078 - val_binary_accuracy: 0.8604 - val_f1: 0.8645 - val_recall: 0.8959 - val_precision: 0.8413
# Epoch 70/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2884 - binary_accuracy: 0.8636 - f1: 0.8674 - recall: 0.8923 - precision: 0.8448 - val_loss: 0.3039 - val_binary_accuracy: 0.8601 - val_f1: 0.8625 - val_recall: 0.8787 - val_precision: 0.8531
# Epoch 71/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2849 - binary_accuracy: 0.8681 - f1: 0.8700 - recall: 0.8884 - precision: 0.8532 - val_loss: 0.3054 - val_binary_accuracy: 0.8583 - val_f1: 0.8597 - val_recall: 0.8698 - val_precision: 0.8569
# Epoch 72/500
# 151/151 [==============================] - 2s 11ms/step - loss: 0.2874 - binary_accuracy: 0.8660 - f1: 0.8672 - recall: 0.8848 - precision: 0.8510 - val_loss: 0.3095 - val_binary_accuracy: 0.8562 - val_f1: 0.8591 - val_recall: 0.8774 - val_precision: 0.8478
# Epoch 73/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2814 - binary_accuracy: 0.8685 - f1: 0.8709 - recall: 0.8897 - precision: 0.8539 - val_loss: 0.3097 - val_binary_accuracy: 0.8593 - val_f1: 0.8601 - val_recall: 0.8659 - val_precision: 0.8607
# Epoch 74/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2888 - binary_accuracy: 0.8674 - f1: 0.8678 - recall: 0.8788 - precision: 0.8582 - val_loss: 0.3092 - val_binary_accuracy: 0.8605 - val_f1: 0.8643 - val_recall: 0.8924 - val_precision: 0.8439
# Epoch 75/500
# 151/151 [==============================] - 2s 13ms/step - loss: 0.2837 - binary_accuracy: 0.8699 - f1: 0.8719 - recall: 0.8939 - precision: 0.8517 - val_loss: 0.3121 - val_binary_accuracy: 0.8591 - val_f1: 0.8610 - val_recall: 0.8752 - val_precision: 0.8534
# Epoch 76/500
# 151/151 [==============================] - 2s 13ms/step - loss: 0.2806 - binary_accuracy: 0.8699 - f1: 0.8723 - recall: 0.8941 - precision: 0.8524 - val_loss: 0.3148 - val_binary_accuracy: 0.8576 - val_f1: 0.8588 - val_recall: 0.8693 - val_precision: 0.8548
# Epoch 77/500
# 151/151 [==============================] - 2s 13ms/step - loss: 0.2818 - binary_accuracy: 0.8694 - f1: 0.8719 - recall: 0.8881 - precision: 0.8572 - val_loss: 0.3120 - val_binary_accuracy: 0.8593 - val_f1: 0.8617 - val_recall: 0.8766 - val_precision: 0.8533
# Epoch 78/500
# 151/151 [==============================] - 2s 13ms/step - loss: 0.2794 - binary_accuracy: 0.8711 - f1: 0.8723 - recall: 0.8906 - precision: 0.8559 - val_loss: 0.3107 - val_binary_accuracy: 0.8575 - val_f1: 0.8580 - val_recall: 0.8612 - val_precision: 0.8613
# Epoch 79/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2767 - binary_accuracy: 0.8746 - f1: 0.8756 - recall: 0.8944 - precision: 0.8585 - val_loss: 0.3090 - val_binary_accuracy: 0.8596 - val_f1: 0.8631 - val_recall: 0.8912 - val_precision: 0.8424
# Epoch 80/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2723 - binary_accuracy: 0.8745 - f1: 0.8771 - recall: 0.8982 - precision: 0.8581 - val_loss: 0.3151 - val_binary_accuracy: 0.8565 - val_f1: 0.8603 - val_recall: 0.8851 - val_precision: 0.8422
# Epoch 81/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2729 - binary_accuracy: 0.8748 - f1: 0.8763 - recall: 0.8948 - precision: 0.8596 - val_loss: 0.3204 - val_binary_accuracy: 0.8583 - val_f1: 0.8610 - val_recall: 0.8811 - val_precision: 0.8480
# Epoch 82/500
# 151/151 [==============================] - 2s 12ms/step - loss: 0.2714 - binary_accuracy: 0.8752 - f1: 0.8774 - recall: 0.8938 - precision: 0.8625 - val_loss: 0.3228 - val_binary_accuracy: 0.8539 - val_f1: 0.8556 - val_recall: 0.8679 - val_precision: 0.8497
# Epoch 83/500
# 151/151 [==============================] - 2s 13ms/step - loss: 0.2766 - binary_accuracy: 0.8728 - f1: 0.8748 - recall: 0.8925 - precision: 0.8588 - val_loss: 0.3212 - val_binary_accuracy: 0.8581 - val_f1: 0.8610 - val_recall: 0.8806 - val_precision: 0.8478
# Epoch 84/500
# 151/151 [==============================] - 2s 13ms/step - loss: 0.2672 - binary_accuracy: 0.8782 - f1: 0.8807 - recall: 0.8997 - precision: 0.8633 - val_loss: 0.3279 - val_binary_accuracy: 0.8570 - val_f1: 0.8595 - val_recall: 0.8737 - val_precision: 0.8518
# tn = 16254, fp = 2636, fn = 2029, tp = 16773
# y_pred: 0 = 18283 | 1 = 19409
# y_true: 0 = 18890 | 1 = 18802
# acc=0.8762|precision=0.8642|recall=0.8921|f1=0.8779|auc=0.9551|aupr=0.9557|pos_acc=0.8921|neg_acc=0.8890
# tn = 3943, fp = 725, fn = 623, tp = 4133
# y_pred: 0 = 4566 | 1 = 4858
# y_true: 0 = 4668 | 1 = 4756
# acc=0.8570|precision=0.8508|recall=0.8690|f1=0.8598|auc=0.9364|aupr=0.9390|pos_acc=0.8690|neg_acc=0.8636
